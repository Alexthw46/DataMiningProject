# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report
from classifiers import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load the dataset and select the features and target to use for the classification.

# %%
import pandas as pd

df = pd.read_csv('../data/new_incidents.csv')

# drop useless columns
df = df.drop(columns=['notes', 'date'])

poverty_df = pd.read_csv('../data/poverty_cleaned.csv')
df = df.merge(poverty_df, on=['state', 'year'])

# %%
# convert state string to int
df['state'] = df['state'].astype('category')
df['state'] = df['state'].cat.codes

df['city_or_county'] = df['city_or_county'].astype('category')
df['city_or_county'] = df['city_or_county'].cat.codes

df['incident_category'] = df['incident_category'].astype('category')
df['incident_category'] = df['incident_category'].cat.codes

df["any_killed"] = df["n_killed"] > 0

df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159432 entries, 0 to 183653
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   state                   159432 non-null  int8
#  1   city_or_county          159432 non-null  int16
#  2   latitude                159432 non-null  float64
#  3   longitude               159432 non-null  float64
#  4   congressional_district  159432 non-null  float64
#  5   avg_age_participants    159432 non-null  float64
#  6   n_participants_adult    159432 non-null  float64
#  7   n_males                 159432 non-null  float64
#  8   n_females               159432 non-null  float64
#  9   n_killed                159432 non-null  int64
#  10  n_injured               159432 non-null  int64
#  11  n_arrested              159432 non-null  int64
#  12  n_unharmed              159432 non-null  int64
#  13  n_participants          159432 non-null  int64
#  14  year                    159432 non-null  int64
#  15  month                   159432 non-null  int64
#  16  day                     159432 non-null  int64
#  17  incident_category       159432 non-null  int8
#  18  kills_to_pov            159432 non-null  float64
#  19  age_to_average          159432 non-null  float64
#  20  par_to_average          159432 non-null  float64
#  21  n_involved              159432 non-null  int64
#  22  minors_to_pop           159432 non-null  float64
#  23  par_to_pop              159432 non-null  float64
#  24  kil_to_p                159432 non-null  float64
#  25  man_to_p                159432 non-null  float64
#  26  fem_to_p                159432 non-null  float64
#  27  arr_to_p                159432 non-null  float64
#  28  unh_to_p                159432 non-null  float64
#  29  inj_to_p                159432 non-null  float64
#  30  n_minors                159432 non-null  float64
#  31  teen_to_m               159432 non-null  float64
#  32  teen_to_f               159432 non-null  float64
#  33  par_to_tot              159432 non-null  float64
#  34  povertyPercentage       159432 non-null  float64
#  35  any_killed              159432 non-null  bool
# dtypes: bool(1), float64(23), int16(1), int64(9), int8(2)
# memory usage: 40.9 MB

# %%
input_columns = ['state', 'longitude', 'latitude', 'year', 'month', 'n_participants',
                 'n_participants_adult', 'n_minors',
                 'n_males', 'n_females',
                 'povertyPercentage', 'n_arrested', 'n_injured']

target_column = ['any_killed']

X = df[input_columns]
y = df[target_column]

# %%
kill_value_count = df['any_killed'].value_counts()

labels = ['no_killed', 'any_killed']
plt.pie(kill_value_count, labels=labels)
plt.show()

# %% [markdown]
# ## Prepare and split the dataset

# %% [markdown]
# Split the dataset into dev and test sets, then into train and validation (70/15/15).
# The distribution of the target variable is maintained in each set. We will try oversampling to reach the 50/50 ratio after the tests with the 70/30 split, as it's still a decent ratio.

# %%
import numpy as np

seed = 42
X_dev, X_test, y_dev, y_test = train_test_split(X, y, random_state=seed, test_size=0.15, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, random_state=seed, test_size=0.18,
                                                  stratify=y_dev)  # for manual cross-validation

print('Dev set size:', len(y_dev), '- Killing ratio:', round(np.count_nonzero(y_dev) / len(y_dev), 2))
print('     Train set size:', len(y_train), '- Killing ratio:', round(np.count_nonzero(y_train) / len(y_train), 2))
print('     Validation set size:', len(y_val), '- Killing ratio:', round(np.count_nonzero(y_val) / len(y_val), 2))
print('Test set size:', len(y_test), '- Killing ratio:', round(np.count_nonzero(y_test) / len(y_test), 2))
# Out:
# Dev set size: 135517 - Killing ratio: 0.29
#      Train set size: 111123 - Killing ratio: 0.29
#      Validation set size: 24394 - Killing ratio: 0.29
# Test set size: 23915 - Killing ratio: 0.29

# %% [markdown]
# Standardize the input data to avoid the bias given by the range of the different attribute

# %%
scaler = StandardScaler()
X_std_dev = scaler.fit_transform(X_dev)
X_std_train = scaler.fit_transform(X_train)
X_std_val = scaler.fit_transform(X_val)
X_std_test = scaler.fit_transform(X_test)

# ravel() is used to convert the y arrays from 2D to 1D
y_dev = y_dev.values.ravel()
y_train = y_train.values.ravel()
y_val = y_val.values.ravel()
y_test = y_test.values.ravel()

# %% [markdown]
# NB: run all above before running a classifier

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
knn_list = []
acc_tr_list = []
acc_val_list = []

for x in range(3, 18):
    # Create KNN classifier
    knn = KNeighborsClassifier(n_neighbors=x)
    knn.fit(X_std_train, y_train)
    acc_tr = knn.score(X_std_train, y_train)
    acc_val = knn.score(X_std_val, y_val)
    # append results
    knn_list.append(knn)
    acc_tr_list.append(acc_tr)
    acc_val_list.append(acc_val)

plt.plot(range(len(acc_tr_list)), acc_tr_list, 'r--', label='training')
plt.plot(range(len(acc_val_list)), acc_val_list, 'b-', label='validation')
plt.ylabel('accuracy')
plt.xlabel('K')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.title('KNN')
plt.axvline(8)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Also try to perform k-fold cross-validation for each k

# %%
cv_scores = []
for k in range(1, 20):
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_std_dev, y_dev, cv=5)  # 5-fold cross-validation
    cv_scores.append(scores.mean())

best_k_cv = np.argmax(cv_scores) + 1  # Add 1 to get the actual k value
best_accuracy_cv = max(cv_scores)

print(f"The best k based on cross-validation accuracy is: {best_k_cv}")
print(f"Corresponding cross-validation accuracy: {best_accuracy_cv}")
# Out:
# The best k based on cross-validation accuracy is: 15
# Corresponding cross-validation accuracy: 0.8540625823169394

# %% [markdown]
# Test both k (8 and 15) and see which one is better

# %%
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(X_std_dev, y_dev)
acc_tr = knn.score(X_std_dev, y_dev)
acc_val = knn.score(X_std_test, y_test)
print(f"Training accuracy: {acc_tr}")
print(f"Test accuracy: {acc_val}")
# Out:
# Training accuracy: 0.8821181106429452
# Test accuracy: 0.8553209282876856

# %%
knn_2 = KNeighborsClassifier(n_neighbors=15)
knn_2.fit(X_std_dev, y_dev)
acc_tr = knn_2.score(X_std_dev, y_dev)
acc_val = knn_2.score(X_std_test, y_test)
print(f"Training accuracy: {acc_tr}")
print(f"Test accuracy: {acc_val}")
# Out:
# Training accuracy: 0.8737944316949166
# Test accuracy: 0.855948149696843

# %%
plot_roc_curves(y_test, [
    (knn.predict_proba(X_std_test)[:, 1], 'KNN (k=8)'),
    (knn_2.predict_proba(X_std_test)[:, 1], 'KNN (k=15)')
])

# %% [markdown]
# # Bayesian Classifier

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB

gnb = GaussianNB()
y_pred = gnb.fit(X_std_train, y_train).predict(X_std_val)
print(classification_report(y_pred, y_val, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    no_killed       0.92      0.74      0.82     21495
#   any_killed       0.21      0.51      0.30      2899
#
#     accuracy                           0.71     24394
#    macro avg       0.56      0.62      0.56     24394
# weighted avg       0.83      0.71      0.76     24394

# %%
bnb = BernoulliNB()
y_pred = bnb.fit(X_std_train, y_train).predict(X_std_val)
print(classification_report(y_pred, y_val, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    no_killed       0.88      0.77      0.82     19903
#   any_killed       0.35      0.55      0.43      4491
#
#     accuracy                           0.73     24394
#    macro avg       0.62      0.66      0.63     24394
# weighted avg       0.78      0.73      0.75     24394

# %%
# test BernoulliNB on test set
y_pred = bnb.fit(X_std_dev, y_dev).predict(X_std_test)
print(classification_report(y_pred, y_test, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    no_killed       0.89      0.77      0.83     19652
#   any_killed       0.35      0.56      0.43      4263
#
#     accuracy                           0.74     23915
#    macro avg       0.62      0.67      0.63     23915
# weighted avg       0.79      0.74      0.76     23915

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_params = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [5, 10, 20, 50],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['sqrt', 'log2', None]
}
best_score_dt, best_decision_tree = grid_search(DecisionTreeClassifier(), X_std_dev, y_dev, dt_params)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters set found:
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# Best accuracy score found:
# 0.8628216252281895

# %%
decision_tree = DecisionTreeClassifier(criterion='gini', max_depth=10, max_features=None, min_samples_leaf=10,
                                       min_samples_split=5,
                                       splitter='best')
print(decision_tree.fit(X_std_dev, y_dev).score(X_std_test, y_test))

plot_roc_curve(y_test, decision_tree.predict_proba(X_std_test)[:, 1], 'Decision Tree')
# Out:
# 0.8637675099310056

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_params = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 10, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10, 20],
    'max_features': ['sqrt', 'log2']
}
best_score_rf, best_random_forest = grid_search(RandomForestClassifier(), X_std_dev, y_dev, rf_params)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# Best parameters set found:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}
# Best accuracy score found:
# 0.873971529953445

# %%
random_forest = RandomForestClassifier(max_depth=20, max_features='sqrt', min_samples_leaf=2, min_samples_split=5,
                                       n_estimators=150)
print(random_forest.fit(X_std_dev, y_dev).score(X_std_test, y_test))

plot_roc_curve(y_test, random_forest.predict_proba(X_std_test)[:, 1], 'Random Forest')
# Out:
# 0.8767719004808697

# %% [markdown]
# # SVM

# %%
import sklearn.svm as svms

# %%
svm_params = {
    "kernel": ["rbf", "sigmoid"],
    "gamma": ["scale", "auto"],
    "C": [0.1, 0.5, 1, 5, 10, 20],
    "max_iter": [100, 200, 300]
}

best_score_svm, svm = grid_search(svms.SVC(), X_std_dev, y_dev, svm_params)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best parameters set found:
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'max_iter': 200}
# Best accuracy score found:
# 0.7089660446259473

# %%
# use better implementation for large dataset (linear kernel)
lsvm_params = {
    "loss": ["hinge", "squared_hinge"],
    "C": [0.1, 0.5, 1, 5, 10],
}

best_score_lsvm, lsvm = grid_search(svms.LinearSVC(penalty='l2', dual='auto'), X_std_dev, y_dev, lsvm_params)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters set found:
# {'C': 5, 'loss': 'hinge'}
# Best accuracy score found:
# 0.7951548140547052

# %%
# polynomial kernel
psvm_params = {
    "degree": [2, 3, 4],
    "C": [0.1, 0.5, 1, 5],
    "max_iter": [100, 200],
    "gamma": ["scale", "auto"]
}
best_score_psvm, psvm = grid_search(svms.SVC(kernel='poly'), X_std_dev, y_dev, psvm_params)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters set found:
# {'C': 1, 'degree': 4, 'gamma': 'scale', 'max_iter': 100}
# Best accuracy score found:
# 0.45738110172305646

# %%
chosen_svm = svms.LinearSVC(penalty='l2', dual='auto', C=5, loss='hinge')
print(chosen_svm.fit(X_std_dev, y_dev).score(X_std_test, y_test))
plot_roc_curve(y_test, chosen_svm.predict(X_std_test), 'Linear SVM')
# Out:
# 0.814007944804516

# %% [markdown]
# # Neural Network

# %%
from sklearn.neural_network import MLPClassifier

nn_params = {
    'hidden_layer_sizes': [(25, 25, 25), (50, 25, 25), (150, 100, 50)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [1e-3, 1e-4],
    'learning_rate': ['adaptive'],
    'max_iter': [50, 100]
}

best_score_nn, neural_network = grid_search(MLPClassifier(early_stopping=True), X_std_dev, y_dev, nn_params)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters set found:
# {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (150, 100, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# Best accuracy score found:
# 0.8702893371131623

# %%
from keras import Sequential
import keras as k
from keras.src import callbacks


def keras_mlp(train_X, train_y, val_X, val_y, optimizer, activation, dropout, epochs):
    neural_net = Sequential(
        [
            k.Input(shape=(13,)),
            k.layers.Dense(units=50, activation=activation),
            k.layers.Dense(units=25, activation=activation),
            k.layers.Dense(units=25, activation=activation),
            k.layers.Dropout(dropout),
            k.layers.Dense(1, "sigmoid")
        ]
    )
    callback = [
        callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=7, cooldown=2, verbose=1, factor=0.25,
                                    min_lr=1e-7,
                                    min_delta=1e-5),
        callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, verbose=1, min_delta=1e-5,
                                restore_best_weights=True)
    ]
    neural_net.compile(optimizer=optimizer, loss=k.losses.BinaryCrossentropy(), metrics=['accuracy'])
    return neural_net.fit(train_X, train_y, batch_size=320, epochs=epochs, verbose=2, validation_data=(val_X, val_y),
                          callbacks=callback), neural_net

# %%
from keras.src.optimizers import Adam

history_adam, adam_model = keras_mlp(X_std_train, y_train, X_std_val, y_val,
                                Adam(learning_rate=1e-4), activation="tanh",
                                dropout=0.3, epochs=150)
plt.plot(history_adam.history['accuracy'])
plt.plot(history_adam.history['val_accuracy'])
plt.title('Adam accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history_adam.history['loss'])
plt.plot(history_adam.history['val_loss'])
plt.title('Adam loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

print(adam_model.evaluate(X_std_test, y_test))
# Out:
# Epoch 1/150
# 348/348 - 2s - 5ms/step - accuracy: 0.7527 - loss: 0.5472 - val_accuracy: 0.7978 - val_loss: 0.4685 - learning_rate: 1.0000e-04
# Epoch 2/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8040 - loss: 0.4484 - val_accuracy: 0.8021 - val_loss: 0.4339 - learning_rate: 1.0000e-04
# Epoch 3/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8105 - loss: 0.4240 - val_accuracy: 0.8074 - val_loss: 0.4144 - learning_rate: 1.0000e-04
# Epoch 4/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8162 - loss: 0.4034 - val_accuracy: 0.8192 - val_loss: 0.3912 - learning_rate: 1.0000e-04
# Epoch 5/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8237 - loss: 0.3816 - val_accuracy: 0.8288 - val_loss: 0.3673 - learning_rate: 1.0000e-04
# Epoch 6/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8322 - loss: 0.3598 - val_accuracy: 0.8405 - val_loss: 0.3475 - learning_rate: 1.0000e-04
# Epoch 7/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8384 - loss: 0.3449 - val_accuracy: 0.8476 - val_loss: 0.3349 - learning_rate: 1.0000e-04
# Epoch 8/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8447 - loss: 0.3342 - val_accuracy: 0.8513 - val_loss: 0.3276 - learning_rate: 1.0000e-04
# Epoch 9/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8492 - loss: 0.3273 - val_accuracy: 0.8535 - val_loss: 0.3230 - learning_rate: 1.0000e-04
# Epoch 10/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8500 - loss: 0.3239 - val_accuracy: 0.8553 - val_loss: 0.3196 - learning_rate: 1.0000e-04
# Epoch 11/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8538 - loss: 0.3197 - val_accuracy: 0.8549 - val_loss: 0.3173 - learning_rate: 1.0000e-04
# Epoch 12/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8533 - loss: 0.3181 - val_accuracy: 0.8563 - val_loss: 0.3156 - learning_rate: 1.0000e-04
# Epoch 13/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8555 - loss: 0.3148 - val_accuracy: 0.8556 - val_loss: 0.3143 - learning_rate: 1.0000e-04
# Epoch 14/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8550 - loss: 0.3136 - val_accuracy: 0.8565 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 15/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8556 - loss: 0.3123 - val_accuracy: 0.8571 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 16/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8561 - loss: 0.3109 - val_accuracy: 0.8559 - val_loss: 0.3105 - learning_rate: 1.0000e-04
# Epoch 17/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8575 - loss: 0.3090 - val_accuracy: 0.8574 - val_loss: 0.3094 - learning_rate: 1.0000e-04
# Epoch 18/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8578 - loss: 0.3077 - val_accuracy: 0.8580 - val_loss: 0.3089 - learning_rate: 1.0000e-04
# Epoch 19/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8578 - loss: 0.3067 - val_accuracy: 0.8580 - val_loss: 0.3081 - learning_rate: 1.0000e-04
# Epoch 20/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8578 - loss: 0.3062 - val_accuracy: 0.8582 - val_loss: 0.3070 - learning_rate: 1.0000e-04
# Epoch 21/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8582 - loss: 0.3056 - val_accuracy: 0.8588 - val_loss: 0.3065 - learning_rate: 1.0000e-04
# Epoch 22/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8588 - loss: 0.3045 - val_accuracy: 0.8589 - val_loss: 0.3056 - learning_rate: 1.0000e-04
# Epoch 23/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8586 - loss: 0.3034 - val_accuracy: 0.8587 - val_loss: 0.3052 - learning_rate: 1.0000e-04
# Epoch 24/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8597 - loss: 0.3027 - val_accuracy: 0.8584 - val_loss: 0.3045 - learning_rate: 1.0000e-04
# Epoch 25/150
# 348/348 - 1s - 2ms/step - accuracy: 0.8597 - loss: 0.3023 - val_accuracy: 0.8594 - val_loss: 0.3040 - learning_rate: 1.0000e-04
# Epoch 26/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8600 - loss: 0.3015 - val_accuracy: 0.8593 - val_loss: 0.3036 - learning_rate: 1.0000e-04
# Epoch 27/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8596 - loss: 0.3013 - val_accuracy: 0.8592 - val_loss: 0.3031 - learning_rate: 1.0000e-04
# Epoch 28/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8600 - loss: 0.3004 - val_accuracy: 0.8601 - val_loss: 0.3024 - learning_rate: 1.0000e-04
# Epoch 29/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8601 - loss: 0.3004 - val_accuracy: 0.8598 - val_loss: 0.3019 - learning_rate: 1.0000e-04
# Epoch 30/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8613 - loss: 0.2997 - val_accuracy: 0.8599 - val_loss: 0.3017 - learning_rate: 1.0000e-04
# Epoch 31/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8610 - loss: 0.2987 - val_accuracy: 0.8599 - val_loss: 0.3016 - learning_rate: 1.0000e-04
# Epoch 32/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2981 - val_accuracy: 0.8606 - val_loss: 0.3008 - learning_rate: 1.0000e-04
# Epoch 33/150
# 348/348 - 1s - 1ms/step - accuracy: 0.8617 - loss: 0.2980 - val_accuracy: 0.8596 - val_loss: 0.3008 - learning_rate: 1.0000e-04
# Epoch 34/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8614 - loss: 0.2980 - val_accuracy: 0.8601 - val_loss: 0.3006 - learning_rate: 1.0000e-04
# Epoch 35/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8616 - loss: 0.2975 - val_accuracy: 0.8597 - val_loss: 0.2999 - learning_rate: 1.0000e-04
# Epoch 36/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8610 - loss: 0.2969 - val_accuracy: 0.8604 - val_loss: 0.2999 - learning_rate: 1.0000e-04
# Epoch 37/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8620 - loss: 0.2962 - val_accuracy: 0.8603 - val_loss: 0.2994 - learning_rate: 1.0000e-04
# Epoch 38/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8620 - loss: 0.2962 - val_accuracy: 0.8606 - val_loss: 0.2992 - learning_rate: 1.0000e-04
# Epoch 39/150
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 348/348 - 0s - 1ms/step - accuracy: 0.8616 - loss: 0.2961 - val_accuracy: 0.8605 - val_loss: 0.2990 - learning_rate: 1.0000e-04
# Epoch 40/150
# 348/348 - 1s - 2ms/step - accuracy: 0.8625 - loss: 0.2957 - val_accuracy: 0.8596 - val_loss: 0.2987 - learning_rate: 2.5000e-05
# Epoch 41/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8621 - loss: 0.2958 - val_accuracy: 0.8607 - val_loss: 0.2986 - learning_rate: 2.5000e-05
# Epoch 42/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8620 - loss: 0.2951 - val_accuracy: 0.8601 - val_loss: 0.2985 - learning_rate: 2.5000e-05
# Epoch 43/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8625 - loss: 0.2946 - val_accuracy: 0.8601 - val_loss: 0.2985 - learning_rate: 2.5000e-05
# Epoch 44/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8623 - loss: 0.2950 - val_accuracy: 0.8598 - val_loss: 0.2985 - learning_rate: 2.5000e-05
# Epoch 45/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8622 - loss: 0.2952 - val_accuracy: 0.8602 - val_loss: 0.2983 - learning_rate: 2.5000e-05
# Epoch 46/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8624 - loss: 0.2948 - val_accuracy: 0.8598 - val_loss: 0.2983 - learning_rate: 2.5000e-05
# Epoch 47/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8626 - loss: 0.2945 - val_accuracy: 0.8599 - val_loss: 0.2982 - learning_rate: 2.5000e-05
# Epoch 48/150
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 348/348 - 0s - 1ms/step - accuracy: 0.8623 - loss: 0.2950 - val_accuracy: 0.8599 - val_loss: 0.2981 - learning_rate: 2.5000e-05
# Epoch 49/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8626 - loss: 0.2947 - val_accuracy: 0.8600 - val_loss: 0.2981 - learning_rate: 6.2500e-06
# Epoch 50/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8623 - loss: 0.2948 - val_accuracy: 0.8599 - val_loss: 0.2981 - learning_rate: 6.2500e-06
# Epoch 51/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8628 - loss: 0.2948 - val_accuracy: 0.8599 - val_loss: 0.2981 - learning_rate: 6.2500e-06
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 41.
# 748/748 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.8599 - loss: 0.2920
# [0.291963130235672, 0.8618855476379395]

# %%
from keras.src.optimizers import SGD

sgd = SGD(learning_rate=1e-3, momentum=0.9, nesterov=True)

sgd_history, sgd_model = keras_mlp(X_std_train, y_train, X_std_val, y_val, sgd, activation="tanh", dropout=0.3,
                               epochs=150)
plt.plot(sgd_history.history['accuracy'])
plt.plot(sgd_history.history['val_accuracy'])
plt.title('SGD accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(sgd_history.history['loss'])
plt.plot(sgd_history.history['val_loss'])
plt.title('SGD loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

sgd_model.fit(X_std_dev, y_dev, batch_size=320, epochs=30, verbose=2)
print(sgd_model.evaluate(X_std_test, y_test))
# Out:
# Epoch 1/150
# 348/348 - 1s - 4ms/step - accuracy: 0.6777 - loss: 0.5922 - val_accuracy: 0.7215 - val_loss: 0.5067 - learning_rate: 0.0010
# Epoch 2/150
# 348/348 - 0s - 1ms/step - accuracy: 0.7501 - loss: 0.4737 - val_accuracy: 0.7599 - val_loss: 0.4466 - learning_rate: 0.0010
# Epoch 3/150
# 348/348 - 0s - 1ms/step - accuracy: 0.7848 - loss: 0.4376 - val_accuracy: 0.7959 - val_loss: 0.4286 - learning_rate: 0.0010
# Epoch 4/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8000 - loss: 0.4224 - val_accuracy: 0.8053 - val_loss: 0.4144 - learning_rate: 0.0010
# Epoch 5/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8097 - loss: 0.4074 - val_accuracy: 0.8120 - val_loss: 0.3981 - learning_rate: 0.0010
# Epoch 6/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8167 - loss: 0.3920 - val_accuracy: 0.8187 - val_loss: 0.3824 - learning_rate: 0.0010
# Epoch 7/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8223 - loss: 0.3785 - val_accuracy: 0.8254 - val_loss: 0.3695 - learning_rate: 0.0010
# Epoch 8/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8273 - loss: 0.3672 - val_accuracy: 0.8324 - val_loss: 0.3586 - learning_rate: 0.0010
# Epoch 9/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8319 - loss: 0.3581 - val_accuracy: 0.8380 - val_loss: 0.3502 - learning_rate: 0.0010
# Epoch 10/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8356 - loss: 0.3501 - val_accuracy: 0.8407 - val_loss: 0.3436 - learning_rate: 0.0010
# Epoch 11/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8381 - loss: 0.3438 - val_accuracy: 0.8437 - val_loss: 0.3383 - learning_rate: 0.0010
# Epoch 12/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8414 - loss: 0.3391 - val_accuracy: 0.8464 - val_loss: 0.3340 - learning_rate: 0.0010
# Epoch 13/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8434 - loss: 0.3352 - val_accuracy: 0.8475 - val_loss: 0.3305 - learning_rate: 0.0010
# Epoch 14/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8451 - loss: 0.3317 - val_accuracy: 0.8495 - val_loss: 0.3277 - learning_rate: 0.0010
# Epoch 15/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8474 - loss: 0.3291 - val_accuracy: 0.8499 - val_loss: 0.3250 - learning_rate: 0.0010
# Epoch 16/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8489 - loss: 0.3256 - val_accuracy: 0.8516 - val_loss: 0.3233 - learning_rate: 0.0010
# Epoch 17/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8501 - loss: 0.3240 - val_accuracy: 0.8530 - val_loss: 0.3219 - learning_rate: 0.0010
# Epoch 18/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8513 - loss: 0.3225 - val_accuracy: 0.8525 - val_loss: 0.3204 - learning_rate: 0.0010
# Epoch 19/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8520 - loss: 0.3205 - val_accuracy: 0.8537 - val_loss: 0.3193 - learning_rate: 0.0010
# Epoch 20/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8516 - loss: 0.3196 - val_accuracy: 0.8540 - val_loss: 0.3185 - learning_rate: 0.0010
# Epoch 21/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8529 - loss: 0.3178 - val_accuracy: 0.8534 - val_loss: 0.3177 - learning_rate: 0.0010
# Epoch 22/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8543 - loss: 0.3170 - val_accuracy: 0.8540 - val_loss: 0.3167 - learning_rate: 0.0010
# Epoch 23/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8537 - loss: 0.3167 - val_accuracy: 0.8541 - val_loss: 0.3160 - learning_rate: 0.0010
# Epoch 24/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8535 - loss: 0.3155 - val_accuracy: 0.8555 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 25/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8550 - loss: 0.3151 - val_accuracy: 0.8553 - val_loss: 0.3151 - learning_rate: 0.0010
# Epoch 26/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8550 - loss: 0.3134 - val_accuracy: 0.8551 - val_loss: 0.3145 - learning_rate: 0.0010
# Epoch 27/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8551 - loss: 0.3129 - val_accuracy: 0.8562 - val_loss: 0.3136 - learning_rate: 0.0010
# Epoch 28/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8553 - loss: 0.3118 - val_accuracy: 0.8549 - val_loss: 0.3131 - learning_rate: 0.0010
# Epoch 29/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8562 - loss: 0.3115 - val_accuracy: 0.8563 - val_loss: 0.3125 - learning_rate: 0.0010
# Epoch 30/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8557 - loss: 0.3106 - val_accuracy: 0.8574 - val_loss: 0.3120 - learning_rate: 0.0010
# Epoch 31/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8559 - loss: 0.3105 - val_accuracy: 0.8569 - val_loss: 0.3116 - learning_rate: 0.0010
# Epoch 32/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8562 - loss: 0.3095 - val_accuracy: 0.8573 - val_loss: 0.3110 - learning_rate: 0.0010
# Epoch 33/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8562 - loss: 0.3093 - val_accuracy: 0.8575 - val_loss: 0.3104 - learning_rate: 0.0010
# Epoch 34/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8566 - loss: 0.3087 - val_accuracy: 0.8572 - val_loss: 0.3100 - learning_rate: 0.0010
# Epoch 35/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8571 - loss: 0.3082 - val_accuracy: 0.8579 - val_loss: 0.3097 - learning_rate: 0.0010
# Epoch 36/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8571 - loss: 0.3076 - val_accuracy: 0.8574 - val_loss: 0.3090 - learning_rate: 0.0010
# Epoch 37/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8579 - loss: 0.3067 - val_accuracy: 0.8575 - val_loss: 0.3085 - learning_rate: 0.0010
# Epoch 38/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8579 - loss: 0.3065 - val_accuracy: 0.8582 - val_loss: 0.3083 - learning_rate: 0.0010
# Epoch 39/150
# 348/348 - 1s - 2ms/step - accuracy: 0.8576 - loss: 0.3061 - val_accuracy: 0.8576 - val_loss: 0.3078 - learning_rate: 0.0010
# Epoch 40/150
# 348/348 - 1s - 1ms/step - accuracy: 0.8582 - loss: 0.3057 - val_accuracy: 0.8576 - val_loss: 0.3071 - learning_rate: 0.0010
# Epoch 41/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8587 - loss: 0.3053 - val_accuracy: 0.8577 - val_loss: 0.3068 - learning_rate: 0.0010
# Epoch 42/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8582 - loss: 0.3044 - val_accuracy: 0.8580 - val_loss: 0.3063 - learning_rate: 0.0010
# Epoch 43/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8585 - loss: 0.3043 - val_accuracy: 0.8581 - val_loss: 0.3059 - learning_rate: 0.0010
# Epoch 44/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8587 - loss: 0.3037 - val_accuracy: 0.8584 - val_loss: 0.3058 - learning_rate: 0.0010
# Epoch 45/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8585 - loss: 0.3037 - val_accuracy: 0.8585 - val_loss: 0.3051 - learning_rate: 0.0010
# Epoch 46/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8583 - loss: 0.3032 - val_accuracy: 0.8587 - val_loss: 0.3049 - learning_rate: 0.0010
# Epoch 47/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8593 - loss: 0.3027 - val_accuracy: 0.8585 - val_loss: 0.3045 - learning_rate: 0.0010
# Epoch 48/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8591 - loss: 0.3023 - val_accuracy: 0.8588 - val_loss: 0.3041 - learning_rate: 0.0010
# Epoch 49/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8592 - loss: 0.3024 - val_accuracy: 0.8587 - val_loss: 0.3039 - learning_rate: 0.0010
# Epoch 50/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8602 - loss: 0.3016 - val_accuracy: 0.8586 - val_loss: 0.3037 - learning_rate: 0.0010
# Epoch 51/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8597 - loss: 0.3016 - val_accuracy: 0.8585 - val_loss: 0.3032 - learning_rate: 0.0010
# Epoch 52/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8603 - loss: 0.3017 - val_accuracy: 0.8589 - val_loss: 0.3029 - learning_rate: 0.0010
# Epoch 53/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8608 - loss: 0.3006 - val_accuracy: 0.8591 - val_loss: 0.3025 - learning_rate: 0.0010
# Epoch 54/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8596 - loss: 0.3003 - val_accuracy: 0.8591 - val_loss: 0.3022 - learning_rate: 0.0010
# Epoch 55/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8605 - loss: 0.3001 - val_accuracy: 0.8582 - val_loss: 0.3020 - learning_rate: 0.0010
# Epoch 56/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8602 - loss: 0.2995 - val_accuracy: 0.8590 - val_loss: 0.3016 - learning_rate: 0.0010
# Epoch 57/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8606 - loss: 0.2994 - val_accuracy: 0.8593 - val_loss: 0.3013 - learning_rate: 0.0010
# Epoch 58/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8610 - loss: 0.2990 - val_accuracy: 0.8591 - val_loss: 0.3011 - learning_rate: 0.0010
# Epoch 59/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8604 - loss: 0.2990 - val_accuracy: 0.8596 - val_loss: 0.3008 - learning_rate: 0.0010
# Epoch 60/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8613 - loss: 0.2984 - val_accuracy: 0.8596 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 61/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8606 - loss: 0.2982 - val_accuracy: 0.8593 - val_loss: 0.3003 - learning_rate: 0.0010
# Epoch 62/150
# 348/348 - 1s - 2ms/step - accuracy: 0.8609 - loss: 0.2983 - val_accuracy: 0.8601 - val_loss: 0.3002 - learning_rate: 0.0010
# Epoch 63/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8614 - loss: 0.2979 - val_accuracy: 0.8590 - val_loss: 0.2999 - learning_rate: 0.0010
# Epoch 64/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2973 - val_accuracy: 0.8596 - val_loss: 0.2996 - learning_rate: 0.0010
# Epoch 65/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8613 - loss: 0.2968 - val_accuracy: 0.8599 - val_loss: 0.2991 - learning_rate: 0.0010
# Epoch 66/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8617 - loss: 0.2969 - val_accuracy: 0.8596 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 67/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8613 - loss: 0.2965 - val_accuracy: 0.8598 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 68/150
# 348/348 - 1s - 2ms/step - accuracy: 0.8618 - loss: 0.2966 - val_accuracy: 0.8596 - val_loss: 0.2987 - learning_rate: 0.0010
# Epoch 69/150
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 348/348 - 0s - 1ms/step - accuracy: 0.8623 - loss: 0.2966 - val_accuracy: 0.8599 - val_loss: 0.2983 - learning_rate: 0.0010
# Epoch 70/150
# 348/348 - 1s - 1ms/step - accuracy: 0.8620 - loss: 0.2955 - val_accuracy: 0.8597 - val_loss: 0.2982 - learning_rate: 2.5000e-04
# Epoch 71/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8629 - loss: 0.2958 - val_accuracy: 0.8595 - val_loss: 0.2982 - learning_rate: 2.5000e-04
# Epoch 72/150
# 348/348 - 0s - 1ms/step - accuracy: 0.8620 - loss: 0.2958 - val_accuracy: 0.8596 - val_loss: 0.2981 - learning_rate: 2.5000e-04
# Epoch 72: early stopping
# Restoring model weights from the end of the best epoch: 62.
# Epoch 1/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8614 - loss: 0.2987
# Epoch 2/30
# 424/424 - 1s - 1ms/step - accuracy: 0.8603 - loss: 0.2988
# Epoch 3/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8607 - loss: 0.2987
# Epoch 4/30
# 424/424 - 1s - 1ms/step - accuracy: 0.8613 - loss: 0.2983
# Epoch 5/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8609 - loss: 0.2985
# Epoch 6/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8616 - loss: 0.2984
# Epoch 7/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8611 - loss: 0.2985
# Epoch 8/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8608 - loss: 0.2974
# Epoch 9/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8611 - loss: 0.2981
# Epoch 10/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8610 - loss: 0.2980
# Epoch 11/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8599 - loss: 0.2982
# Epoch 12/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8610 - loss: 0.2978
# Epoch 13/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8613 - loss: 0.2981
# Epoch 14/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8609 - loss: 0.2978
# Epoch 15/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8610 - loss: 0.2979
# Epoch 16/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8617 - loss: 0.2971
# Epoch 17/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8612 - loss: 0.2974
# Epoch 18/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2974
# Epoch 19/30
# 424/424 - 1s - 1ms/step - accuracy: 0.8613 - loss: 0.2974
# Epoch 20/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8611 - loss: 0.2973
# Epoch 21/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8616 - loss: 0.2973
# Epoch 22/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8616 - loss: 0.2971
# Epoch 23/30
# 424/424 - 1s - 1ms/step - accuracy: 0.8614 - loss: 0.2967
# Epoch 24/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2969
# Epoch 25/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8616 - loss: 0.2972
# Epoch 26/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2968
# Epoch 27/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2969
# Epoch 28/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8613 - loss: 0.2964
# Epoch 29/30
# 424/424 - 1s - 1ms/step - accuracy: 0.8613 - loss: 0.2971
# Epoch 30/30
# 424/424 - 0s - 1ms/step - accuracy: 0.8615 - loss: 0.2963
# 748/748 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.8607 - loss: 0.2923
# [0.29253900051116943, 0.8622576594352722]

# %%
plot_roc_curves(y_test, [
    (adam_model.predict(X_std_test).ravel(), 'Neural Network (Adam)'),
    (sgd_model.predict(X_std_test).ravel(), 'Neural Network (SGD)')
])
# Out:
# 748/748 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# 748/748 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step

# %% [markdown]
# # With SMOTE
#
# We'll try now to use SMOTE to balance the dataset and have a 50-50 ratio of incidents with and without killings.
# Then we'll retry the best classifiers on this new dataset to see if there are substantial differences.

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X, y = sm.fit_resample(X, y)

plt.pie(y.value_counts(), labels=labels)
plt.show()

# %%
X_dev, X_test, y_dev, y_test = train_test_split(X, y, random_state=seed, test_size=0.15, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, random_state=seed, test_size=0.18, stratify=y_dev)

print('Dev set size:', len(y_dev), '- Killing ratio:', round(np.count_nonzero(y_dev) / len(y_dev), 2))
print('     Train set size:', len(y_train), '- Killing ratio:', round(np.count_nonzero(y_train) / len(y_train), 2))
print('     Validation set size:', len(y_val), '- Killing ratio:', round(np.count_nonzero(y_val) / len(y_val), 2))
print('Test set size:', len(y_test), '- Killing ratio:', round(np.count_nonzero(y_test) / len(y_test), 2))
# Out:
# Dev set size: 193296 - Killing ratio: 0.5
#      Train set size: 158502 - Killing ratio: 0.5
#      Validation set size: 34794 - Killing ratio: 0.5
# Test set size: 34112 - Killing ratio: 0.5

# %%
scaler = StandardScaler()
X_std_dev = scaler.fit_transform(X_dev)
X_std_train = scaler.fit_transform(X_train)
X_std_val = scaler.fit_transform(X_val)
X_std_test = scaler.fit_transform(X_test)

# ravel() is used to convert the y arrays from 2D to 1D
y_dev = y_dev.values.ravel()
y_train = y_train.values.ravel()
y_val = y_val.values.ravel()
y_test = y_test.values.ravel()

# %% [markdown]
# Retry the best classifier on a more balanced dataset

# %%
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(X_std_train, y_train)
acc_tr = knn.score(X_std_dev, y_dev)
acc_val = knn.score(X_std_test, y_test)
print(f"Training accuracy: {acc_tr}")
print(f"Test accuracy: {acc_val}")
# Out:
# Training accuracy: 0.8984148663190133
# Test accuracy: 0.8796024859287055

# %%
bnb = BernoulliNB()
y_pred = bnb.fit(X_std_dev, y_dev).predict(X_std_test)
print(classification_report(y_pred, y_test, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    no_killed       0.77      0.75      0.76     17566
#   any_killed       0.74      0.76      0.75     16546
#
#     accuracy                           0.75     34112
#    macro avg       0.75      0.75      0.75     34112
# weighted avg       0.75      0.75      0.75     34112

# %%
from sklearn.tree import DecisionTreeClassifier

dt_params = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [5, 10, 20, 50],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['sqrt', 'log2', None]
}
best_score_dt, best_decision_tree = grid_search(DecisionTreeClassifier(), X_std_dev, y_dev, dt_params)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters set found:
# {'criterion': 'entropy', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# Best accuracy score found:
# 0.8865160052048603

# %%
decision_tree = DecisionTreeClassifier(criterion='entropy', max_depth=20, max_features=None, min_samples_leaf=1,
                                       min_samples_split=2,
                                       splitter='best')
print("Same Parameters: " + str(decision_tree.fit(X_std_dev, y_dev).score(X_std_test, y_test)))
print("Updated Parameters: " + str(best_decision_tree.fit(X_std_dev, y_dev).score(X_std_test, y_test)))
# Out:
# Same Parameters: 0.8000117260787992
# Updated Parameters: 0.8064024390243902

# %%
from sklearn.ensemble import RandomForestClassifier

rf_params = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 10, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10, 20],
    'max_features': ['sqrt', 'log2']
}
best_score_rf, best_random_forest = grid_search(RandomForestClassifier(), X_std_dev, y_dev, rf_params)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# Best parameters set found:
# {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 150}
# Best accuracy score found:
# 0.9100653791082726

# %%
random_forest = RandomForestClassifier(max_depth=20, max_features='sqrt', min_samples_leaf=2, min_samples_split=5,
                                       n_estimators=150)
print("Same Parameters: " + str(random_forest.fit(X_std_dev, y_dev).score(X_std_test, y_test)))
print("Updated Parameters: " + str(best_random_forest.fit(X_std_dev, y_dev).score(X_std_test, y_test)))
# Out:
# Same Parameters: 0.8004221388367729
# Updated Parameters: 0.7986045966228893

# %%
chosen_svm = svms.LinearSVC(penalty='l2', dual='auto', C=5, loss='hinge')
print(chosen_svm.fit(X_std_dev, y_dev).score(X_std_test, y_test))
# Out:
# 0.8574108818011257

# %%
from keras.optimizers import Adam

history, adam_model = keras_mlp(X_std_train, y_train, X_std_val, y_val,
                                Adam(learning_rate=1e-4), activation="tanh",
                                dropout=0.3, epochs=150)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

eval = adam_model.evaluate(X_std_test, y_test)
print(eval)
# Out:
# Epoch 1/150
# 496/496 - 2s - 3ms/step - accuracy: 0.7735 - loss: 0.5253 - val_accuracy: 0.8507 - val_loss: 0.4284 - learning_rate: 1.0000e-04
# Epoch 2/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8531 - loss: 0.4189 - val_accuracy: 0.8573 - val_loss: 0.3841 - learning_rate: 1.0000e-04
# Epoch 3/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8572 - loss: 0.3789 - val_accuracy: 0.8625 - val_loss: 0.3499 - learning_rate: 1.0000e-04
# Epoch 4/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8598 - loss: 0.3529 - val_accuracy: 0.8658 - val_loss: 0.3304 - learning_rate: 1.0000e-04
# Epoch 5/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8623 - loss: 0.3385 - val_accuracy: 0.8688 - val_loss: 0.3198 - learning_rate: 1.0000e-04
# Epoch 6/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8645 - loss: 0.3295 - val_accuracy: 0.8709 - val_loss: 0.3134 - learning_rate: 1.0000e-04
# Epoch 7/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8681 - loss: 0.3227 - val_accuracy: 0.8732 - val_loss: 0.3088 - learning_rate: 1.0000e-04
# Epoch 8/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8693 - loss: 0.3175 - val_accuracy: 0.8750 - val_loss: 0.3054 - learning_rate: 1.0000e-04
# Epoch 9/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8717 - loss: 0.3125 - val_accuracy: 0.8760 - val_loss: 0.3030 - learning_rate: 1.0000e-04
# Epoch 10/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8736 - loss: 0.3096 - val_accuracy: 0.8766 - val_loss: 0.3007 - learning_rate: 1.0000e-04
# Epoch 11/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8750 - loss: 0.3063 - val_accuracy: 0.8771 - val_loss: 0.2991 - learning_rate: 1.0000e-04
# Epoch 12/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8758 - loss: 0.3046 - val_accuracy: 0.8772 - val_loss: 0.2977 - learning_rate: 1.0000e-04
# Epoch 13/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8763 - loss: 0.3027 - val_accuracy: 0.8779 - val_loss: 0.2963 - learning_rate: 1.0000e-04
# Epoch 14/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8767 - loss: 0.3012 - val_accuracy: 0.8777 - val_loss: 0.2949 - learning_rate: 1.0000e-04
# Epoch 15/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8773 - loss: 0.2992 - val_accuracy: 0.8776 - val_loss: 0.2939 - learning_rate: 1.0000e-04
# Epoch 16/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8775 - loss: 0.2986 - val_accuracy: 0.8782 - val_loss: 0.2933 - learning_rate: 1.0000e-04
# Epoch 17/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8777 - loss: 0.2974 - val_accuracy: 0.8786 - val_loss: 0.2925 - learning_rate: 1.0000e-04
# Epoch 18/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8783 - loss: 0.2966 - val_accuracy: 0.8785 - val_loss: 0.2917 - learning_rate: 1.0000e-04
# Epoch 19/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8783 - loss: 0.2957 - val_accuracy: 0.8786 - val_loss: 0.2914 - learning_rate: 1.0000e-04
# Epoch 20/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8787 - loss: 0.2952 - val_accuracy: 0.8786 - val_loss: 0.2903 - learning_rate: 1.0000e-04
# Epoch 21/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8787 - loss: 0.2944 - val_accuracy: 0.8785 - val_loss: 0.2898 - learning_rate: 1.0000e-04
# Epoch 22/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8793 - loss: 0.2932 - val_accuracy: 0.8787 - val_loss: 0.2894 - learning_rate: 1.0000e-04
# Epoch 23/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8793 - loss: 0.2930 - val_accuracy: 0.8785 - val_loss: 0.2890 - learning_rate: 1.0000e-04
# Epoch 24/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8791 - loss: 0.2927 - val_accuracy: 0.8791 - val_loss: 0.2886 - learning_rate: 1.0000e-04
# Epoch 25/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8793 - loss: 0.2918 - val_accuracy: 0.8794 - val_loss: 0.2879 - learning_rate: 1.0000e-04
# Epoch 26/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8794 - loss: 0.2915 - val_accuracy: 0.8792 - val_loss: 0.2875 - learning_rate: 1.0000e-04
# Epoch 27/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8797 - loss: 0.2911 - val_accuracy: 0.8794 - val_loss: 0.2873 - learning_rate: 1.0000e-04
# Epoch 28/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8797 - loss: 0.2910 - val_accuracy: 0.8795 - val_loss: 0.2869 - learning_rate: 1.0000e-04
# Epoch 29/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8797 - loss: 0.2902 - val_accuracy: 0.8789 - val_loss: 0.2866 - learning_rate: 1.0000e-04
# Epoch 30/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8799 - loss: 0.2902 - val_accuracy: 0.8798 - val_loss: 0.2863 - learning_rate: 1.0000e-04
# Epoch 31/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8800 - loss: 0.2900 - val_accuracy: 0.8797 - val_loss: 0.2862 - learning_rate: 1.0000e-04
# Epoch 32/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8809 - loss: 0.2894 - val_accuracy: 0.8795 - val_loss: 0.2858 - learning_rate: 1.0000e-04
# Epoch 33/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8809 - loss: 0.2886 - val_accuracy: 0.8797 - val_loss: 0.2853 - learning_rate: 1.0000e-04
# Epoch 34/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8801 - loss: 0.2890 - val_accuracy: 0.8793 - val_loss: 0.2852 - learning_rate: 1.0000e-04
# Epoch 35/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8809 - loss: 0.2881 - val_accuracy: 0.8798 - val_loss: 0.2851 - learning_rate: 1.0000e-04
# Epoch 36/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8811 - loss: 0.2878 - val_accuracy: 0.8803 - val_loss: 0.2850 - learning_rate: 1.0000e-04
# Epoch 37/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8807 - loss: 0.2877 - val_accuracy: 0.8795 - val_loss: 0.2844 - learning_rate: 1.0000e-04
# Epoch 38/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8807 - loss: 0.2873 - val_accuracy: 0.8806 - val_loss: 0.2843 - learning_rate: 1.0000e-04
# Epoch 39/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8807 - loss: 0.2873 - val_accuracy: 0.8809 - val_loss: 0.2842 - learning_rate: 1.0000e-04
# Epoch 40/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8810 - loss: 0.2869 - val_accuracy: 0.8802 - val_loss: 0.2838 - learning_rate: 1.0000e-04
# Epoch 41/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8814 - loss: 0.2864 - val_accuracy: 0.8800 - val_loss: 0.2836 - learning_rate: 1.0000e-04
# Epoch 42/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8810 - loss: 0.2862 - val_accuracy: 0.8804 - val_loss: 0.2838 - learning_rate: 1.0000e-04
# Epoch 43/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8811 - loss: 0.2864 - val_accuracy: 0.8807 - val_loss: 0.2834 - learning_rate: 1.0000e-04
# Epoch 44/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8814 - loss: 0.2858 - val_accuracy: 0.8807 - val_loss: 0.2831 - learning_rate: 1.0000e-04
# Epoch 45/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8812 - loss: 0.2858 - val_accuracy: 0.8804 - val_loss: 0.2829 - learning_rate: 1.0000e-04
# Epoch 46/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8816 - loss: 0.2852 - val_accuracy: 0.8811 - val_loss: 0.2831 - learning_rate: 1.0000e-04
# Epoch 47/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8816 - loss: 0.2853 - val_accuracy: 0.8809 - val_loss: 0.2828 - learning_rate: 1.0000e-04
# Epoch 48/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8819 - loss: 0.2846 - val_accuracy: 0.8811 - val_loss: 0.2825 - learning_rate: 1.0000e-04
# Epoch 49/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8821 - loss: 0.2844 - val_accuracy: 0.8811 - val_loss: 0.2829 - learning_rate: 1.0000e-04
# Epoch 50/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8822 - loss: 0.2844 - val_accuracy: 0.8811 - val_loss: 0.2822 - learning_rate: 1.0000e-04
# Epoch 51/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8817 - loss: 0.2843 - val_accuracy: 0.8808 - val_loss: 0.2819 - learning_rate: 1.0000e-04
# Epoch 52/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8822 - loss: 0.2842 - val_accuracy: 0.8812 - val_loss: 0.2816 - learning_rate: 1.0000e-04
# Epoch 53/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8825 - loss: 0.2840 - val_accuracy: 0.8811 - val_loss: 0.2815 - learning_rate: 1.0000e-04
# Epoch 54/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8823 - loss: 0.2840 - val_accuracy: 0.8814 - val_loss: 0.2825 - learning_rate: 1.0000e-04
# Epoch 55/150
# 496/496 - 1s - 2ms/step - accuracy: 0.8822 - loss: 0.2838 - val_accuracy: 0.8815 - val_loss: 0.2812 - learning_rate: 1.0000e-04
# Epoch 56/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8829 - loss: 0.2834 - val_accuracy: 0.8820 - val_loss: 0.2814 - learning_rate: 1.0000e-04
# Epoch 57/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8824 - loss: 0.2832 - val_accuracy: 0.8813 - val_loss: 0.2812 - learning_rate: 1.0000e-04
# Epoch 58/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8827 - loss: 0.2826 - val_accuracy: 0.8820 - val_loss: 0.2807 - learning_rate: 1.0000e-04
# Epoch 59/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8826 - loss: 0.2826 - val_accuracy: 0.8818 - val_loss: 0.2806 - learning_rate: 1.0000e-04
# Epoch 60/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8829 - loss: 0.2826 - val_accuracy: 0.8816 - val_loss: 0.2808 - learning_rate: 1.0000e-04
# Epoch 61/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8828 - loss: 0.2824 - val_accuracy: 0.8817 - val_loss: 0.2803 - learning_rate: 1.0000e-04
# Epoch 62/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8832 - loss: 0.2823 - val_accuracy: 0.8820 - val_loss: 0.2803 - learning_rate: 1.0000e-04
# Epoch 63/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8826 - loss: 0.2823 - val_accuracy: 0.8823 - val_loss: 0.2802 - learning_rate: 1.0000e-04
# Epoch 64/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8830 - loss: 0.2818 - val_accuracy: 0.8821 - val_loss: 0.2801 - learning_rate: 1.0000e-04
# Epoch 65/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8833 - loss: 0.2818 - val_accuracy: 0.8815 - val_loss: 0.2800 - learning_rate: 1.0000e-04
# Epoch 66/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8834 - loss: 0.2812 - val_accuracy: 0.8822 - val_loss: 0.2797 - learning_rate: 1.0000e-04
# Epoch 67/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8833 - loss: 0.2812 - val_accuracy: 0.8823 - val_loss: 0.2800 - learning_rate: 1.0000e-04
# Epoch 68/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8832 - loss: 0.2811 - val_accuracy: 0.8824 - val_loss: 0.2801 - learning_rate: 1.0000e-04
# Epoch 69/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8834 - loss: 0.2814 - val_accuracy: 0.8824 - val_loss: 0.2793 - learning_rate: 1.0000e-04
# Epoch 70/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8834 - loss: 0.2806 - val_accuracy: 0.8829 - val_loss: 0.2792 - learning_rate: 1.0000e-04
# Epoch 71/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8836 - loss: 0.2807 - val_accuracy: 0.8827 - val_loss: 0.2791 - learning_rate: 1.0000e-04
# Epoch 72/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8834 - loss: 0.2811 - val_accuracy: 0.8819 - val_loss: 0.2791 - learning_rate: 1.0000e-04
# Epoch 73/150
# 496/496 - 1s - 3ms/step - accuracy: 0.8834 - loss: 0.2806 - val_accuracy: 0.8828 - val_loss: 0.2789 - learning_rate: 1.0000e-04
# Epoch 74/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8836 - loss: 0.2804 - val_accuracy: 0.8820 - val_loss: 0.2788 - learning_rate: 1.0000e-04
# Epoch 75/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8836 - loss: 0.2804 - val_accuracy: 0.8827 - val_loss: 0.2786 - learning_rate: 1.0000e-04
# Epoch 76/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8837 - loss: 0.2802 - val_accuracy: 0.8828 - val_loss: 0.2792 - learning_rate: 1.0000e-04
# Epoch 77/150
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 496/496 - 1s - 1ms/step - accuracy: 0.8838 - loss: 0.2802 - val_accuracy: 0.8820 - val_loss: 0.2785 - learning_rate: 1.0000e-04
# Epoch 78/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8836 - loss: 0.2796 - val_accuracy: 0.8831 - val_loss: 0.2784 - learning_rate: 2.5000e-05
# Epoch 79/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8837 - loss: 0.2793 - val_accuracy: 0.8826 - val_loss: 0.2784 - learning_rate: 2.5000e-05
# Epoch 80/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8837 - loss: 0.2794 - val_accuracy: 0.8829 - val_loss: 0.2783 - learning_rate: 2.5000e-05
# Epoch 81/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8841 - loss: 0.2796 - val_accuracy: 0.8827 - val_loss: 0.2785 - learning_rate: 2.5000e-05
# Epoch 82/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8841 - loss: 0.2793 - val_accuracy: 0.8831 - val_loss: 0.2783 - learning_rate: 2.5000e-05
# Epoch 83/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8845 - loss: 0.2794 - val_accuracy: 0.8827 - val_loss: 0.2784 - learning_rate: 2.5000e-05
# Epoch 84/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8842 - loss: 0.2793 - val_accuracy: 0.8829 - val_loss: 0.2784 - learning_rate: 2.5000e-05
# Epoch 85/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8839 - loss: 0.2793 - val_accuracy: 0.8829 - val_loss: 0.2783 - learning_rate: 2.5000e-05
# Epoch 86/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8838 - loss: 0.2793 - val_accuracy: 0.8831 - val_loss: 0.2782 - learning_rate: 2.5000e-05
# Epoch 87/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8843 - loss: 0.2795 - val_accuracy: 0.8828 - val_loss: 0.2783 - learning_rate: 2.5000e-05
# Epoch 88/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8838 - loss: 0.2797 - val_accuracy: 0.8829 - val_loss: 0.2781 - learning_rate: 2.5000e-05
# Epoch 89/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8841 - loss: 0.2791 - val_accuracy: 0.8830 - val_loss: 0.2781 - learning_rate: 2.5000e-05
# Epoch 90/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8841 - loss: 0.2792 - val_accuracy: 0.8829 - val_loss: 0.2781 - learning_rate: 2.5000e-05
# Epoch 91/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8841 - loss: 0.2794 - val_accuracy: 0.8830 - val_loss: 0.2781 - learning_rate: 2.5000e-05
# Epoch 92/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8845 - loss: 0.2791 - val_accuracy: 0.8828 - val_loss: 0.2781 - learning_rate: 2.5000e-05
# Epoch 93/150
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 496/496 - 1s - 1ms/step - accuracy: 0.8838 - loss: 0.2795 - val_accuracy: 0.8828 - val_loss: 0.2781 - learning_rate: 2.5000e-05
# Epoch 94/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8840 - loss: 0.2792 - val_accuracy: 0.8830 - val_loss: 0.2781 - learning_rate: 6.2500e-06
# Epoch 95/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8843 - loss: 0.2790 - val_accuracy: 0.8831 - val_loss: 0.2780 - learning_rate: 6.2500e-06
# Epoch 96/150
# 496/496 - 1s - 1ms/step - accuracy: 0.8843 - loss: 0.2792 - val_accuracy: 0.8830 - val_loss: 0.2781 - learning_rate: 6.2500e-06
# Epoch 96: early stopping
# Restoring model weights from the end of the best epoch: 86.
# 1066/1066 ━━━━━━━━━━━━━━━━━━━━ 1s 577us/step - accuracy: 0.8853 - loss: 0.2748
# [0.2744288444519043, 0.8848205804824829]

# %%
rocs = [
    (knn.predict_proba(X_std_test)[:, 1], 'KNN'),
    (decision_tree.predict_proba(X_std_test)[:, 1], 'Decision Tree'),
    (random_forest.predict_proba(X_std_test)[:, 1], 'Random Forest'),
    (chosen_svm.predict(X_std_test), 'Linear SVM'),
    (adam_model.predict(X_std_test).ravel(), 'Neural Network (Adam)')
]

plot_roc_curves(y_test, rocs)
# Out:
# 1066/1066 ━━━━━━━━━━━━━━━━━━━━ 1s 527us/step
